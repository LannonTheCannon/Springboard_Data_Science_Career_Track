# %%
# Importing the Libraries 

# Let's import the pandas, numpy libraries as pd, and np respectively. 
import pandas as pd
import numpy as np

# Load the pyplot collection of functions from matplotlib, as plt 
import matplotlib.pyplot as plt

# %%
# Loading the Data

# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# **Cleaning, Transforming and Visualizing**
#
# 1. Each variable has a column
# 2. Each observation forms a row

# %%
# First, lets use .shape feature of pandas DataFrame to look at the number of rows and columns
properties.shape
# Out:
# (336, 49)

# %%
# using the .head() method, let's check out the state of our dataset 
properties.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>City of London</th>
#       <th>Barking &amp; Dagenham</th>
#       <th>Barnet</th>
#       <th>Bexley</th>
#       <th>Brent</th>
#       <th>Bromley</th>
#       <th>Camden</th>
#       <th>Croydon</th>
#       <th>Ealing</th>
#       <th>...</th>
#       <th>NORTH WEST</th>
#       <th>YORKS &amp; THE HUMBER</th>
#       <th>EAST MIDLANDS</th>
#       <th>WEST MIDLANDS</th>
#       <th>EAST OF ENGLAND</th>
#       <th>LONDON</th>
#       <th>SOUTH EAST</th>
#       <th>SOUTH WEST</th>
#       <th>Unnamed: 47</th>
#       <th>England</th>
#     </tr>
#   </thead>
#   <tbody>
# ...

# %% [markdown]
# 1. Find the observations of interest as rows and the features as columns
#     1. The column headings are the particular boroughs which is your observations of interest
#     2. The first column contains datetime objects that capture a particular month and year, which is a variable.
#
# 2. Most of the other cell-values are the average property values of the borough corresponding to the time stamp.

# %% [markdown]
# **Transposition**
#
# 1. You transpose a table when you flip the columns into rows, and vice versa.
# 2. If you transpose the DataFrame then the borough names will become the row indices, and the date time objects will become the column headers.

# %%
# Let's transpose the data 

properties_T = properties.T 

print(properties_T.shape)
print(properties_T.info())



# Let's check the head of our new transposed DataFrame 
properties_T.head()
# Out:
# (49, 336)
# <class 'pandas.core.frame.DataFrame'>
# Index: 49 entries, Unnamed: 0 to England
# Columns: 336 entries, 0 to 335
# dtypes: object(336)
# memory usage: 130.1+ KB
# None
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#       <th>9</th>
#       <th>...</th>
#       <th>326</th>
#       <th>327</th>
#       <th>328</th>
#       <th>329</th>
#       <th>330</th>
#       <th>331</th>
#       <th>332</th>
#       <th>333</th>
#       <th>334</th>
#       <th>335</th>
#     </tr>
#   </thead>
# ...

# %%
# To confirm what our row indices are, let's call the .index 

properties_T.index
# Out:
# Index(['Unnamed: 0', 'City of London', 'Barking & Dagenham', 'Barnet',
#        'Bexley', 'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow',
#        'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth', 'Lewisham',
#        'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark',
#        'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth',
#        'Westminster', 'Unnamed: 34', 'Inner London', 'Outer London',
#        'Unnamed: 37', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'Unnamed: 47', 'England'],
#       dtype='object')

# %%
# Our suspicion was correct. 
# Call the .reset_index method on properties_T to reset the indices. 

properties_T = properties_T.reset_index()

# %%
# Now let's check out our dataframe indices again
properties_T.columns
# Out:
# Index(['index',       0,       1,       2,       3,       4,       5,       6,
#              7,       8,
#        ...
#            326,     327,     328,     329,     330,     331,     332,     333,
#            334,     335],
#       dtype='object', length=337)

# %%
# The indices are now a row a numerical RangeIndex, exactly what you want. 
properties_T.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>index</th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#       <th>...</th>
#       <th>326</th>
#       <th>327</th>
#       <th>328</th>
#       <th>329</th>
#       <th>330</th>
#       <th>331</th>
#       <th>332</th>
#       <th>333</th>
#       <th>334</th>
#       <th>335</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Unnamed: 0</td>
#       <td>NaT</td>
#       <td>1995-01-01 00:00:00</td>
#       <td>1995-02-01 00:00:00</td>
# ...

# %%
# To confirm that our DataFrame's columns are mainly just integers, call the .columns feature 
properties_T.columns
# Out:
# Index(['index',       0,       1,       2,       3,       4,       5,       6,
#              7,       8,
#        ...
#            326,     327,     328,     329,     330,     331,     332,     333,
#            334,     335],
#       dtype='object', length=337)

# %%
# Call the iloc[] method on the properties_T Dataframe
properties_T.iloc[[0]]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>index</th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#       <th>...</th>
#       <th>326</th>
#       <th>327</th>
#       <th>328</th>
#       <th>329</th>
#       <th>330</th>
#       <th>331</th>
#       <th>332</th>
#       <th>333</th>
#       <th>334</th>
#       <th>335</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Unnamed: 0</td>
#       <td>NaT</td>
#       <td>1995-01-01 00:00:00</td>
#       <td>1995-02-01 00:00:00</td>
# ...

# %%
properties_T.columns = properties_T.iloc[0]

# Check out the Dataframe again 
properties_T.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>NaN</th>
#       <th>1995-01-01 00:00:00</th>
#       <th>1995-02-01 00:00:00</th>
#       <th>1995-03-01 00:00:00</th>
#       <th>1995-04-01 00:00:00</th>
#       <th>1995-05-01 00:00:00</th>
#       <th>1995-06-01 00:00:00</th>
#       <th>1995-07-01 00:00:00</th>
#       <th>1995-08-01 00:00:00</th>
#       <th>...</th>
#       <th>2022-02-01 00:00:00</th>
#       <th>2022-03-01 00:00:00</th>
#       <th>2022-04-01 00:00:00</th>
#       <th>2022-05-01 00:00:00</th>
#       <th>2022-06-01 00:00:00</th>
#       <th>2022-07-01 00:00:00</th>
#       <th>2022-08-01 00:00:00</th>
# ...

# %%
# Drop the row at index 0! 
# A good way to reassign properties_T with the retun value of calling the DataFrame drop() method, passing 0 as the index

properties_T = properties_T.drop(0)

# Now check that our dataframe looks legit 
properties_T.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>NaN</th>
#       <th>1995-01-01 00:00:00</th>
#       <th>1995-02-01 00:00:00</th>
#       <th>1995-03-01 00:00:00</th>
#       <th>1995-04-01 00:00:00</th>
#       <th>1995-05-01 00:00:00</th>
#       <th>1995-06-01 00:00:00</th>
#       <th>1995-07-01 00:00:00</th>
#       <th>1995-08-01 00:00:00</th>
#       <th>...</th>
#       <th>2022-02-01 00:00:00</th>
#       <th>2022-03-01 00:00:00</th>
#       <th>2022-04-01 00:00:00</th>
#       <th>2022-05-01 00:00:00</th>
#       <th>2022-06-01 00:00:00</th>
#       <th>2022-07-01 00:00:00</th>
#       <th>2022-08-01 00:00:00</th>
# ...

# %%
# we see that there are some values that have Unnamed: 0 which are virtually unusuable 
properties_T = properties_T.rename(columns = {'Unnamed: 0': 'London_Borough', pd.NaT: 'ID'})
properties_T.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>London_Borough</th>
#       <th>ID</th>
#       <th>1995-01-01 00:00:00</th>
#       <th>1995-02-01 00:00:00</th>
#       <th>1995-03-01 00:00:00</th>
#       <th>1995-04-01 00:00:00</th>
#       <th>1995-05-01 00:00:00</th>
#       <th>1995-06-01 00:00:00</th>
#       <th>1995-07-01 00:00:00</th>
#       <th>1995-08-01 00:00:00</th>
#       <th>...</th>
#       <th>2022-02-01 00:00:00</th>
#       <th>2022-03-01 00:00:00</th>
#       <th>2022-04-01 00:00:00</th>
#       <th>2022-05-01 00:00:00</th>
#       <th>2022-06-01 00:00:00</th>
#       <th>2022-07-01 00:00:00</th>
#       <th>2022-08-01 00:00:00</th>
# ...

# %%
# Find out exactly how many columns
properties_T.columns
# Out:
# Index([   'London_Borough',                'ID', 1995-01-01 00:00:00,
#        1995-02-01 00:00:00, 1995-03-01 00:00:00, 1995-04-01 00:00:00,
#        1995-05-01 00:00:00, 1995-06-01 00:00:00, 1995-07-01 00:00:00,
#        1995-08-01 00:00:00,
#        ...
#        2022-02-01 00:00:00, 2022-03-01 00:00:00, 2022-04-01 00:00:00,
#        2022-05-01 00:00:00, 2022-06-01 00:00:00, 2022-07-01 00:00:00,
#        2022-08-01 00:00:00, 2022-09-01 00:00:00, 2022-10-01 00:00:00,
#        2022-11-01 00:00:00],
#       dtype='object', name=0, length=337)

# %%
# Now we need to melt the columns into a single variable
clean_properties = pd.melt(properties_T, id_vars = ['London_Borough', 'ID'])

# %%
clean_properties.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>London_Borough</th>
#       <th>ID</th>
#       <th>0</th>
#       <th>value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>City of London</td>
#       <td>E09000001</td>
#       <td>1995-01-01</td>
#       <td>91448.98487</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Barking &amp; Dagenham</td>
#       <td>E09000002</td>
#       <td>1995-01-01</td>
#       <td>50460.2266</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Barnet</td>
#       <td>E09000003</td>
#       <td>1995-01-01</td>
#       <td>93284.51832</td>
#     </tr>
#     <tr>
# ...

# %%
# Rename the columns
clean_properties = clean_properties.rename(columns = {0: 'Month', 'value': 'Average_Price'})

# Check out the dataframe 
clean_properties.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>London_Borough</th>
#       <th>ID</th>
#       <th>Month</th>
#       <th>Average_Price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>City of London</td>
#       <td>E09000001</td>
#       <td>1995-01-01</td>
#       <td>91448.98487</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Barking &amp; Dagenham</td>
#       <td>E09000002</td>
#       <td>1995-01-01</td>
#       <td>50460.2266</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Barnet</td>
#       <td>E09000003</td>
#       <td>1995-01-01</td>
#       <td>93284.51832</td>
#     </tr>
#     <tr>
# ...

# %%
# Check out the datatypes attribute 
clean_properties.dtypes
# Out:
# <pre>London_Borough            object
# ID                        object
# Month             datetime64[ns]
# Average_Price             object
# dtype: object</pre>

# %%
# Change the average_price column to numerical type. specifically, a float 
clean_properties['Average_Price'] = pd.to_numeric(clean_properties['Average_Price'])

# %%
clean_properties.dtypes
# Out:
# <pre>London_Borough            object
# ID                        object
# Month             datetime64[ns]
# Average_Price            float64
# dtype: object</pre>

# %%
# To see if there are any missing values, we should call the count() method on our DataFrame
clean_properties.count()
# Out:
# <pre>London_Borough    16080
# ID                15075
# Month             16080
# Average_Price     15075
# dtype: int64</pre>

# %%
# We can see that there are fewer data points in some of the columns. 
# Since there are only 32 London boroughs, check out the unique values of the 'London_Borough' column to see if they're all there.
clean_properties['London_Borough'].unique()
# Out:
# <pre>array(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster', 'Unnamed: 34',
#        'Inner London', 'Outer London', 'Unnamed: 37', 'NORTH EAST',
#        'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS',
#        'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST',
#        'SOUTH WEST', 'Unnamed: 47', 'England'], dtype=object)</pre>

# %%
# AHA! Some of the strings are not London Boroughs. 
# See what information is contained in rows where London_Boroughs is Unnamed and if there's nothing valuable
# you can drop them. 
# Subset the clean_properties Dataframe on this condition
clean_properties[clean_properties['London_Borough'] == 'Unnamed: 34'].head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>London_Borough</th>
#       <th>ID</th>
#       <th>Month</th>
#       <th>Average_Price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>33</th>
#       <td>Unnamed: 34</td>
#       <td>NaN</td>
#       <td>1995-01-01</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>81</th>
#       <td>Unnamed: 34</td>
#       <td>NaN</td>
#       <td>1995-02-01</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>129</th>
#       <td>Unnamed: 34</td>
#       <td>NaN</td>
#       <td>1995-03-01</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>177</th>
#       <td>Unnamed: 34</td>
# ...

# %%
clean_properties[clean_properties['London_Borough'] == 'Unnamed: 37'].head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>London_Borough</th>
#       <th>ID</th>
#       <th>Month</th>
#       <th>Average_Price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>36</th>
#       <td>Unnamed: 37</td>
#       <td>NaN</td>
#       <td>1995-01-01</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>84</th>
#       <td>Unnamed: 37</td>
#       <td>NaN</td>
#       <td>1995-02-01</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>132</th>
#       <td>Unnamed: 37</td>
#       <td>NaN</td>
#       <td>1995-03-01</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>180</th>
#       <td>Unnamed: 37</td>
# ...

# %%
# Let's look at how many rows have NAs as their value for ID 
# To this end, subset clean_properties on the condition: clean_properties['ID'].isna()
# Notice that this line does not actually reassign a new value to clean properties 
clean_properties[clean_properties['ID'].isna()]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>London_Borough</th>
#       <th>ID</th>
#       <th>Month</th>
#       <th>Average_Price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>33</th>
#       <td>Unnamed: 34</td>
#       <td>NaN</td>
#       <td>1995-01-01</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>Unnamed: 37</td>
#       <td>NaN</td>
#       <td>1995-01-01</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>Unnamed: 47</td>
#       <td>NaN</td>
#       <td>1995-01-01</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>81</th>
#       <td>Unnamed: 34</td>
# ...

# %%
# You always have a choice about how to deal with Null (NaN values)
# 1. filterting on notna()
# 2. reassigning on dropna() 

# Make a new variable called NaNFreeDF1 and assign it the result of filtering clean_properties on the condition
NaNFreeDF1 = clean_properties[clean_properties['Average_Price'].notna()]
NaNFreeDF1.head(48)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>London_Borough</th>
#       <th>ID</th>
#       <th>Month</th>
#       <th>Average_Price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>City of London</td>
#       <td>E09000001</td>
#       <td>1995-01-01</td>
#       <td>91448.98487</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Barking &amp; Dagenham</td>
#       <td>E09000002</td>
#       <td>1995-01-01</td>
#       <td>50460.22660</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Barnet</td>
#       <td>E09000003</td>
#       <td>1995-01-01</td>
#       <td>93284.51832</td>
#     </tr>
#     <tr>
# ...

# %%
# If we need a count 
NaNFreeDF1.count()
# Out:
# <pre>London_Borough    15075
# ID                15075
# Month             15075
# Average_Price     15075
# dtype: int64</pre>

# %%
# For completeness, use dropna() 
NaNFreeDF2 = clean_properties.dropna() 
NaNFreeDF2.head(48)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>London_Borough</th>
#       <th>ID</th>
#       <th>Month</th>
#       <th>Average_Price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>City of London</td>
#       <td>E09000001</td>
#       <td>1995-01-01</td>
#       <td>91448.98487</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Barking &amp; Dagenham</td>
#       <td>E09000002</td>
#       <td>1995-01-01</td>
#       <td>50460.22660</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Barnet</td>
#       <td>E09000003</td>
#       <td>1995-01-01</td>
#       <td>93284.51832</td>
#     </tr>
#     <tr>
# ...

# %%
# Now lets do a count
NaNFreeDF2.count()
# Out:
# <pre>London_Borough    15075
# ID                15075
# Month             15075
# Average_Price     15075
# dtype: int64</pre>

# %%
NaNFreeDF2['London_Borough'].unique()
# Out:
# <pre>array(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster', 'Inner London',
#        'Outer London', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'England'], dtype=object)</pre>

# %%
print(clean_properties.shape)
print(NaNFreeDF1.shape)
print(NaNFreeDF2.shape)
# Out:
# (16080, 4)
# (15075, 4)
# (15075, 4)

# %%
# Drop the rest of the invalid 'London Borough' values 

# An elegant way to do this is to make a list of all those invalid values, then use the isin() method
# combined with the negation operator ~, to remove those values. Let's call these nonBoroughs

nonBoroughs = ['Inner London', 'Outer London', 
               'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER', 
               'EAST MIDLANDS', 'WEST MIDLANDS',
              'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST', 
              'SOUTH WEST', 'England']

NaNFreeDF2[NaNFreeDF2.London_Borough.isin(nonBoroughs)]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>London_Borough</th>
#       <th>ID</th>
#       <th>Month</th>
#       <th>Average_Price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>34</th>
#       <td>Inner London</td>
#       <td>E13000001</td>
#       <td>1995-01-01</td>
#       <td>78251.97650</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>Outer London</td>
#       <td>E13000002</td>
#       <td>1995-01-01</td>
#       <td>72958.79836</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>NORTH EAST</td>
#       <td>E12000001</td>
#       <td>1995-01-01</td>
#       <td>42076.35411</td>
#     </tr>
#     <tr>
# ...

# %%
# You can now just put the negation operator ~ before the filter statement to get 
# just those rows whose values for London_Borough is not in the nonBoroughs list: 

NaNFreeDF2[~NaNFreeDF2.London_Borough.isin(nonBoroughs)]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>London_Borough</th>
#       <th>ID</th>
#       <th>Month</th>
#       <th>Average_Price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>City of London</td>
#       <td>E09000001</td>
#       <td>1995-01-01</td>
#       <td>91448.98487</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Barking &amp; Dagenham</td>
#       <td>E09000002</td>
#       <td>1995-01-01</td>
#       <td>50460.22660</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Barnet</td>
#       <td>E09000003</td>
#       <td>1995-01-01</td>
#       <td>93284.51832</td>
#     </tr>
#     <tr>
# ...

# %%
NaNFreeDF2.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>London_Borough</th>
#       <th>ID</th>
#       <th>Month</th>
#       <th>Average_Price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>City of London</td>
#       <td>E09000001</td>
#       <td>1995-01-01</td>
#       <td>91448.98487</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Barking &amp; Dagenham</td>
#       <td>E09000002</td>
#       <td>1995-01-01</td>
#       <td>50460.22660</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Barnet</td>
#       <td>E09000003</td>
#       <td>1995-01-01</td>
#       <td>93284.51832</td>
#     </tr>
#     <tr>
# ...

# %%
# Make a new variable called df which typically what data scientists typically name their 
# final analysis ready DataFrame

df = NaNFreeDF2

df.head()

df.dtypes
# Out:
# <pre>London_Borough            object
# ID                        object
# Month             datetime64[ns]
# Average_Price            float64
# dtype: object</pre>

# %%
# Visualizing the Data

# Time to get a visual idea of the price shift occuring in the London Boroughs 
# First of all, make a variable called camden_prices, and assign it the result of filtering
# df on df['London_Borough'] == 'Camden'

camden_prices = df[df['London_Borough'] == 'Camden']

# Make a variable called ax. Assign it the result of calling the plot() method and plugging in the
# following values as parameters 

ax = camden_prices.plot(kind='line', x='Month', y='Average_Price')
ax.set_ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
# To limit the amount of temporal data_points you have, it would be useful to extract the year
# from every value in our Month column. 300 is more datapoints than you need 

# To this end, you'll apply a lambda function, the logic works as follows

# 1. Look through the Month column
# 2. Extract the year from each individual value in that column 
# 3. Store that corresponding year as a separate column

# %%
# Try this yourself. 
df['Year'] = df['Month'].apply(lambda t: t.year)

df.tail()
# Out:
# <ipython-input-44-dd7012b918ac>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year'] = df['Month'].apply(lambda t: t.year)
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>London_Borough</th>
#       <th>ID</th>
#       <th>Month</th>
#       <th>Average_Price</th>
#       <th>Year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>16074</th>
#       <td>EAST OF ENGLAND</td>
# ...

# %%
# To calculate the mean house price for each year, you first need to group by the London_Borough
# and Year columns

# Make a new variable called dfg, and assign it in the result of calling the groupby() method, 
# on df. Plug the parameters by = ['Borough','Year'] 

# To get the mean() of the result you'll chain that onto the end. 

# Using the groupby will help you to calculate the mean for each year and for each Borough 
# As you can see the variables Borough and Year are now indices 

dfg = df.groupby(by = ['London_Borough', 'Year']).mean()
dfg.sample(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Average_Price</th>
#     </tr>
#     <tr>
#       <th>London_Borough</th>
#       <th>Year</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Southwark</th>
#       <th>2015</th>
#       <td>467867.518742</td>
#     </tr>
#     <tr>
#       <th>Islington</th>
#       <th>2000</th>
#       <td>192634.091992</td>
#     </tr>
#     <tr>
#       <th>NORTH EAST</th>
#       <th>2006</th>
#       <td>128206.993850</td>
#     </tr>
#     <tr>
#       <th>Kingston upon Thames</th>
#       <th>2005</th>
#       <td>251156.254508</td>
#     </tr>
#     <tr>
# ...

# %%
# Let's reset the index for our new Dataframe dfg, and call the head() method on it 
dfg = dfg.reset_index()

dfg.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>London_Borough</th>
#       <th>Year</th>
#       <th>Average_Price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Barking &amp; Dagenham</td>
#       <td>1995</td>
#       <td>51817.969390</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Barking &amp; Dagenham</td>
#       <td>1996</td>
#       <td>51718.192690</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Barking &amp; Dagenham</td>
#       <td>1997</td>
#       <td>55974.262309</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Barking &amp; Dagenham</td>
#       <td>1998</td>
# ...

# %%
# You'll want to creat a function that will calculate a ratio of house_prices, that compares 
# prices of a hosue in 2018 to the price of ahouse in 1998 

def create_price_ratio(d): 
    y1998 = float(d['Average_Price'][d['Year'] == 1998])
    y2018 = float(d['Average_Price'][d['Year'] == 2018])

    ratio = [y2018/ y1998]
    return ratio

# %%
# Test out the function by calling it with the following arguemtn 

create_price_ratio(dfg[dfg['London_Borough'] == 'Barking & Dagenham'])
# Out:
# [4.89661861291754]

# %%
# Now let's declare a for loop that will iterate through each of the unique elements of
# THe London_Borough' column of our DataFrame dfg

final = {}

for b in dfg['London_Borough'].unique(): 
    borough = dfg[dfg['London_Borough'] == b]
    final[b] = create_price_ratio(borough)

print(final)
# Out:
# {'Barking & Dagenham': [4.89661861291754], 'Barnet': [4.358195917538044], 'Bexley': [4.248977046127877], 'Brent': [4.8945544971392865], 'Bromley': [4.094784685333876], 'Camden': [4.935353408884261], 'City of London': [5.30162037758761], 'Croydon': [4.201100280024766], 'EAST MIDLANDS': [3.632734672087703], 'EAST OF ENGLAND': [4.166900547724157], 'Ealing': [4.311450902121834], 'Enfield': [4.263471583495811], 'England': [3.810452978397399], 'Greenwich': [4.7630363473291935], 'Hackney': [6.198285561008663], 'Hammersmith & Fulham': [4.13779810193623], 'Haringey': [5.134624964136042], 'Harrow': [4.0591964329643195], 'Havering': [4.325230371335307], 'Hillingdon': [4.2002730803844575], 'Hounslow': [3.976409106143329], 'Inner London': [5.170857506254785], 'Islington': [4.844048012802297], 'Kensington & Chelsea': [5.082465066092464], 'Kingston upon Thames': [4.270549521484271], 'LONDON': [4.679776249632861], 'Lambeth': [4.957751163514062], 'Lewisham': [5.449221041059686], 'Merton': [4.74127331
# ...

# %%
# Now we have a dictionary with data about the ratio of average prices borough between 1998 
# 2018, but you can make it even prettier by converting it to a DataFrame

# Make a variable called df_ratios 

df_ratios = pd.DataFrame(final)

# %%
df_ratios.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Barking &amp; Dagenham</th>
#       <th>Barnet</th>
#       <th>Bexley</th>
#       <th>Brent</th>
#       <th>Bromley</th>
#       <th>Camden</th>
#       <th>City of London</th>
#       <th>Croydon</th>
#       <th>EAST MIDLANDS</th>
#       <th>EAST OF ENGLAND</th>
#       <th>...</th>
#       <th>SOUTH EAST</th>
#       <th>SOUTH WEST</th>
#       <th>Southwark</th>
#       <th>Sutton</th>
#       <th>Tower Hamlets</th>
#       <th>WEST MIDLANDS</th>
#       <th>Waltham Forest</th>
#       <th>Wandsworth</th>
#       <th>Westminster</th>
#       <th>YORKS &amp; THE HUMBER</th>
#     </tr>
#   </thead>
# ...

# %%
# All we need to do now is transpose it, and reset the index! 

df_ratios_T = df_ratios.T 
df_ratios = df_ratios_T.reset_index() 
df_ratios.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>index</th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Barking &amp; Dagenham</td>
#       <td>4.896619</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Barnet</td>
#       <td>4.358196</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Bexley</td>
#       <td>4.248977</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Brent</td>
#       <td>4.894554</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Bromley</td>
#       <td>4.094785</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Now let's just rename the 'index column as 'London_Borough' and the '0' column to '2018'
df_ratios.rename(columns = {'index': 'Borough', 0: '2018'}, inplace = True)
df_ratios.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Borough</th>
#       <th>2018</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Barking &amp; Dagenham</td>
#       <td>4.896619</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Barnet</td>
#       <td>4.358196</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Bexley</td>
#       <td>4.248977</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Brent</td>
#       <td>4.894554</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Bromley</td>
#       <td>4.094785</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Let's sort in descending order and select the top 15 boroughs 
# Make a variable called top15 and assign it in the result of calling
# sort_values() on df_ratios 

top_15 = df_ratios.sort_values(by = '2018', ascending = False).head(15)

# %%
print(top_15)
# Out:
#                  Borough      2018
# 14               Hackney  6.198286
# 41        Waltham Forest  5.834756
# 37             Southwark  5.516485
# 27              Lewisham  5.449221
# 43           Westminster  5.353565
# 31                Newham  5.305390
# 6         City of London  5.301620
# 21          Inner London  5.170858
# 16              Haringey  5.134625
# 23  Kensington & Chelsea  5.082465
# 26               Lambeth  4.957751
# 5                 Camden  4.935353
# 0     Barking & Dagenham  4.896619
# 3                  Brent  4.894554
# 22             Islington  4.844048

# %%
# Let's plot for boroughs that have seen the greatest changes in price

# Make a variable called ax. assign it the result of filtering top15 on Borough 
# and 2018 then calling plot() with the parameter kind = 'bar'

ax = top_15[['Borough', '2018']].plot(kind='bar')
ax.set_xticklabels(top_15.Borough)
# Out:
# [Text(0, 0, 'Hackney'),
#  Text(1, 0, 'Waltham Forest'),
#  Text(2, 0, 'Southwark'),
#  Text(3, 0, 'Lewisham'),
#  Text(4, 0, 'Westminster'),
#  Text(5, 0, 'Newham'),
#  Text(6, 0, 'City of London'),
#  Text(7, 0, 'Inner London'),
#  Text(8, 0, 'Haringey'),
#  Text(9, 0, 'Kensington & Chelsea'),
#  Text(10, 0, 'Lambeth'),
#  Text(11, 0, 'Camden'),
#  Text(12, 0, 'Barking & Dagenham'),
#  Text(13, 0, 'Brent'),
#  Text(14, 0, 'Islington')]
